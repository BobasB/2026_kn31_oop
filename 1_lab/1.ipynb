# %% [markdown]
# # Вчимось програмувати

# %% [markdown]
# > створюємо декілька комірок

# %%
print("Перша комірка запускається успішно")
# Out:
# Перша комірка запускається успішно

# %%
print("Друга комірка")
# Out:
# Друга комірка

# %%
print("Завершуємо присати код")
# Out:
# Завершуємо присати код
